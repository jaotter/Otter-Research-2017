# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
hdulist = fits.open('nsa.fits')
tbdata = hdulist[1].data
masses =  tbdata['MASS']
sSFR = tbdata['B300']
z = tbdata['Z']
hdulist.close()

# %%
fig = plt.figure(1)
ax = fig.add_subplot(1,1,1)

# %%
ax.scatter(masses, sSFR)
ax.set_xlabel('stellar mass (Msun)')
ax.set_ylabel('sSFR')
ax.set_xlim(1E8, 1E13)
ax.semilogx()
# Out:
# []

# %%
plt.show()

# %%
fig2 = plt.figure(2)
ax2 = fig2.add_subplot(1,1,1)

# %%
ax2.scatter(masses, z)
ax2.set_xlabel('stellar mass (Msun)')
ax2.set_ylabel('redshift')
ax2.set_ylim(0.03, 0.06)
ax2.set_xlim(1E9, 1E13)
ax2.semilogx()
# Out:
# []

# %%
plt.show()
